# %% [markdown]
# ## This is a python script, that creates a large number of python files. The script needs to be modified for each setting of L and r to create 3150 scripts for the jobs (this number can be scaled). Each single python file saves the number of catalogs with a test statistic equal or bigger than the test statistic of the original catalog. <br> <br> <br>
# ```python
# scripts_dir="/data/user/simonpick/scrambling_and_matching_test/python_scripts"
# for i in range(0,50):
#     batch_file = "{0:s}/catalog_generation_and_matching{1:n}.py".format(scripts_dir, i)
#     script1="\
# import os, sys, math\n\
# import pandas as pd\n\
# import numpy as np\n\
# from astropy import units as u\n\
# from astropy.coordinates import SkyCoord\n\
# from haversine import haversine_vector, Unit\n\
# original = pd.read_csv('/data/user/simonpick/scrambling_and_matching_test/data/original_catalog.csv')\n\
# num_of_stifting_positions = 1000000\n\
# shifting_distance = np.sqrt(np.random.uniform(0, 100, num_of_stifting_positions))\n\
# angle = np.random.uniform(0, 360, num_of_stifting_positions)\n\
# ra_shift = np.sin(angle * (np.pi / 180.0)) * shifting_distance\n\
# dec_shift = np.cos(angle * (np.pi / 180.0)) * shifting_distance\n\
# def generate_catalog():\n\
# \tcatalog = ([ra+np.random.choice(ra_shift) for ra in original['RA']], [dec+np.random.choice(dec_shift) for dec in original['DEC']])\n\
# \tfor j in range(1177):\n\
# \t\twhile np.logical_or(catalog[1][j] > -5, np.logical_or(catalog[1][j] < -85, np.logical_or(catalog[0][j] > 360, catalog[0][j] < 0))):\n\
# \t\t\tcatalog[0][j] = original['RA'][j] + np.random.choice(ra_shift)\n\
# \t\t\tcatalog[1][j] = original['DEC'][j] + np.random.choice(dec_shift)\n\
# \tcatalog_gal = SkyCoord(ra=catalog[0]*u.degree, dec=catalog[1]*u.degree, frame='icrs').galactic\n\
# \tfor j in range(1177):\n\
# \t\twhile np.logical_or(0 < catalog_gal.b.value[j] < 10, -10 < catalog_gal.b.value[j] < 0):\n\
# \t\t\tdec_gal = np.random.choice(dec_shift)\n\
# \t\t\tif np.logical_and(original['DEC'][j] + dec_gal < -5, original['DEC'][j] + dec_gal > -85):\n\
# \t\t\t\tra_gal = np.random.choice(ra_shift)\n\
# \t\t\t\tcatalog[0][j] = original['RA'][j] + ra_gal\n\
# \t\t\t\tcatalog[1][j] = original['DEC'][j] + dec_gal\n\
# \t\t\t\tcatalog_gal.b.value[j] = SkyCoord(ra=catalog[0][j]*u.degree, dec=catalog[1][j]*u.degree, frame='icrs').galactic.b.value\n\
# \treturn catalog\n\
# neutrino_hotspots = pd.read_csv('/data/user/simonpick/scrambling_and_matching_test/data/buson_neutrino_hotspots_35.csv').to_numpy()\n\
# def match_catalog(catalog, r, neutrino_hotspots):\n\
# \tneutrino_hotspots = list(zip(neutrino_hotspots[:,1], neutrino_hotspots[:,0]))\n\
# \tcatalog = list(zip(catalog[1], catalog[0]))\n\
# \tresult = sum(haversine_vector(neutrino_hotspots,catalog,unit=Unit.DEGREES, normalize=True, comb=True) < r)\n\
# \treturn len(result[result != 0])\n\
# count = 0\n\
# num_of_catalogs = 10000\n\
# for num in range(num_of_catalogs):\n\
# \tif match_catalog(generate_catalog(), 0.4, neutrino_hotspots) > 4:\n\
# \t\tcount += 1\n\
# output_dir = '/home/simonpick/output/'\n\
# outfname = '{0:s}"
#     script2="\
# /output{0:n}.txt'.format(output_dir)\n\
# f = open(outfname, 'w')\n\
# f.write(str(count))\n\
# f.close()\n".format(i)
#     with open(batch_file, "w") as f:
#         f.write(str(script1+script2))
# ```

# %% [markdown]
# ## To get the final number of catalogs with a TS >= than the original TS (call it M), one has to add up all the integers of all output-files. The pre-trial p-value can be calculated by dividing (M+1) by the total number of generated catalogs+1. <br> <br>
#
# ```python
# import numpy as np
# matches = []
# i=0
# while i<50:
#     try:
#         matches.append(int(np.loadtxt(f"/home/simonpick/output/output{i}.txt", dtype=str)))
#         i+=1
#     except:
#         i+=1
# L1r1 = sum(matches)
# l11 = len(matches)
#
# matches = []
# i=50
# while i<100:
#     try:
#         matches.append(int(np.loadtxt(f"/home/simonpick/output/output{i}.txt", dtype=str)))
#         i+=1
#     except:
#         i+=1
# L1r2 = sum(matches)
# l12 = len(matches)
#
# matches = []
# i=100
# while i<150:
#     try:
#         matches.append(int(np.loadtxt(f"/home/simonpick/output/output{i}.txt", dtype=str)))
#         i+=1
#     except:
#         i+=1
# L1r3 = sum(matches)
# l13 = len(matches)
#
# matches = []
# i=150
# while i<200:
#     try:
#         matches.append(int(np.loadtxt(f"/home/simonpick/output/output{i}.txt", dtype=str)))
#         i+=1
#     except:
#         i+=1
# L1r4 = sum(matches)
# l14 = len(matches)
#
# matches = []
# i=200
# while i<250:
#     try:
#         matches.append(int(np.loadtxt(f"/home/simonpick/output/output{i}.txt", dtype=str)))
#         i+=1
#     except:
#         i+=1
# L1r5 = sum(matches)
# l15 = len(matches)
#
# matches = []
# i=250
# while i<300:
#     try:
#         matches.append(int(np.loadtxt(f"/home/simonpick/output/output{i}.txt", dtype=str)))
#         i+=1
#     except:
#         i+=1
# L1r6 = sum(matches)
# l16 = len(matches)
#
# matches = []
# i=300
# while i<350:
#     try:
#         matches.append(int(np.loadtxt(f"/home/simonpick/output/output{i}.txt", dtype=str)))
#         i+=1
#     except:
#         i+=1
# L1r7 = sum(matches)
# l17 = len(matches)
#
#
#
#
# matches = []
# i=350
# while i<700:
#     try:
#         matches.append(int(np.loadtxt(f"/home/simonpick/output/output{i}.txt", dtype=str)))
#         i+=1
#     except:
#         i+=1
# L2r1 = sum(matches)
# l21 = len(matches)
#
# matches = []
# i=700
# while i<1050:
#     try:
#         matches.append(int(np.loadtxt(f"/home/simonpick/output/output{i}.txt", dtype=str)))
#         i+=1
#     except:
#         i+=1
# L2r2 = sum(matches)
# l22 = len(matches)
#
# matches = []
# i=1050
# while i<1400:
#     try:
#         matches.append(int(np.loadtxt(f"/home/simonpick/output/output{i}.txt", dtype=str)))
#         i+=1
#     except:
#         i+=1
# L2r3 = sum(matches)
# l23 = len(matches)
#
# matches = []
# i=1400
# while i<1750:
#     try:
#         matches.append(int(np.loadtxt(f"/home/simonpick/output/output{i}.txt", dtype=str)))
#         i+=1
#     except:
#         i+=1
# L2r4 = sum(matches)
# l24 = len(matches)
#
# matches = []
# i=1750
# while i<2100:
#     try:
#         matches.append(int(np.loadtxt(f"/home/simonpick/output/output{i}.txt", dtype=str)))
#         i+=1
#     except:
#         i+=1
# L2r5 = sum(matches)
# l25 = len(matches)
#
# matches = []
# i=2100
# while i<2450:
#     try:
#         matches.append(int(np.loadtxt(f"/home/simonpick/output/output{i}.txt", dtype=str)))
#         i+=1
#     except:
#         i+=1
# L2r6 = sum(matches)
# l26 = len(matches)
#
# matches = []
# i=2450
# while i<2800:
#     try:
#         matches.append(int(np.loadtxt(f"/home/simonpick/output/output{i}.txt", dtype=str)))
#         i+=1
#     except:
#         i+=1
# L2r7 = sum(matches)
# l27 = len(matches)
#
#
#
#
# matches = []
# i=2800
# while i<2850:
#     try:
#         matches.append(int(np.loadtxt(f"/home/simonpick/output/output{i}.txt", dtype=str)))
#         i+=1
#     except:
#         i+=1
# L3r1 = sum(matches)
# l31 = len(matches)
#
# matches = []
# i=2850
# while i<2900:
#     try:
#         matches.append(int(np.loadtxt(f"/home/simonpick/output/output{i}.txt", dtype=str)))
#         i+=1
#     except:
#         i+=1
# L3r2 = sum(matches)
# l32 = len(matches)
#
# matches = []
# i=2900
# while i<2950:
#     try:
#         matches.append(int(np.loadtxt(f"/home/simonpick/output/output{i}.txt", dtype=str)))
#         i+=1
#     except:
#         i+=1
# L3r3 = sum(matches)
# l33 = len(matches)
#
# matches = []
# i=2950
# while i<3000:
#     try:
#         matches.append(int(np.loadtxt(f"/home/simonpick/output/output{i}.txt", dtype=str)))
#         i+=1
#     except:
#         i+=1
# L3r4 = sum(matches)
# l34 = len(matches)
#
# matches = []
# i=3000
# while i<3050:
#     try:
#         matches.append(int(np.loadtxt(f"/home/simonpick/output/output{i}.txt", dtype=str)))
#         i+=1
#     except:
#         i+=1
# L3r5 = sum(matches)
# l35 = len(matches)
#
# matches = []
# i=3050
# while i<3100:
#     try:
#         matches.append(int(np.loadtxt(f"/home/simonpick/output/output{i}.txt", dtype=str)))
#         i+=1
#     except:
#         i+=1
# L3r6 = sum(matches)
# l36 = len(matches)
#
# matches = []
# i=3100
# while i<3150:
#     try:
#         matches.append(int(np.loadtxt(f"/home/simonpick/output/output{i}.txt", dtype=str)))
#         i+=1
#     except:
#         i+=1
# L3r7 = sum(matches)
# l37 = len(matches)
#
#
#
#
# print(f"{L1r1/(1+l11*7000):e},{(L1r2)/(1+l12*7000):e},{L1r3/(1+l13*7000):e},{L1r4/(1+l14*7000):e},{L1r5/(1+l15*7000):e},{L1r6/(1+l16*7000):e},{L1r7/(1+l17*7000):e}") # L = 3.5
# print(f"{L2r1/(1+l21*7000):e},{L2r2/(1+l22*7000):e},{L2r3/(1+l23*7000):e},{(L2r4-1)/(1+l24*7000):e},{(2+L2r5)/(1+l25*7000):e},{(L2r6-2)/(1+l26*7000):e},{(L2r7-2)/(1+l27*7000):e}") # L = 4.0
# print(f"{(1+L3r1)/(1+l31*7000):e},{(1+L3r2)/(1+l32*7000):e},{(1+L3r3)/(1+l33*7000):e},{(1+L3r4)/(1+l34*7000):e},{(1+L3r5)/(1+l35*7000):e},{(1+L3r6)/(1+l36*7000):e},{(1+L3r7)/(1+l37*7000):e}") # L = 4.5
# ```
