# %% [markdown]
# # Files:

# %%
from IPython.display import IFrame

# %%
IFrame(src='catalog_generation_and_matching.py', width=1100, height=1300)
# Out:
#         <iframe
#             width="1100"
#             height="1300"
#             src="catalog_generation_and_matching.py"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
IFrame(src='job0.sh', width=500, height=100)
# Out:
#         <iframe
#             width="500"
#             height="100"
#             src="job0.sh"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# test.sub

#executable              = /home/simon/condor/job$(Process).sh
#log                     = /home/simon/condor/log/logs_$(Cluster)_$(Process).log
#output                  = /home/simon/condor/output/empty_output/output_$(Cluster)_$(Process).txt
#error                   = /home/simon/condor/error/errors_$(Cluster)_$(Process).txt
#should_transfer_files   = Yes
#when_to_transfer_output = ON_EXIT
#queue 1

# %% [markdown]
# # Results:

# %% [markdown]
# The output of catalog_generation_and_matching.py above is stored as a .csv file and can be opened with pandas

# %%
import pandas as pd
pd.read_csv("/home/simon/condor/output/output_test.csv")
# Out:
#    L1r1  L1r2  L1r3  L1r4  L1r5  L1r6  L1r7  L2r1  L2r2  L2r3  ...  L2r5  \
# 0     1     0     0     0     0     1     2     0     2     0  ...     2
# 1     0     0     4    10     1     2     1     0     0     2  ...     4
# 2     0     1     1     3     3     2     3     1     0     2  ...     1
# 3     0     1     1     1     0    10     0     0     2     2  ...     1
# 4     2     1     2     1     1     5     1     0     0     1  ...     3
# 5     2     0     2     3     0     2     7     0     1     1  ...     0
# 6     1     1     0     3     3     2     3     0     2     1  ...     0
# 7     3     0     1     2     3     4     9     1     1     2  ...     1
# 8     9     3     0     3     2     1     6     2     0     0  ...     3
# 9     1     0     1     1     2     2     5     2     4     0  ...     0
#
#    L2r6  L2r7  L3r1  L3r2  L3r3  L3r4  L3r5  L3r6  L3r7
# 0     1     2     0     0     0     1     0     1     0
# ...

# %% [markdown]
# Runtime: It currently takes approx. **11 sec** to generate one catalog and match it with all 21 L and r settings

# %% [markdown]
# A test run with 10,000 catalogs resulted in the following outcome:<br/>
# Highest Test Statistics achieved for each setting of L (1000 mock catalogs):<br/>
# <br/>
# L=3.5   --->    14 matches (original catalog: 44)<br/>
#             r=0.65, r=0.7 (2x)
# <br/>
# L=4.0   --->    10 matches  (original catalog: 19)<br/>
#             r=0.65, r=0.7
# <br/>
# L=4.5   --->    5 matches   (original catalog: 9)<br/>
#             r=0.55, r=0.6 (3x), r=0.65 (3x), r=0.7 (3x)
